# %% [markdown]
# <a href="https://colab.research.google.com/github/chuddynich-code/Machine-Learning-Portfolio-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

data =[1,2,3,4]
print(data)
# Out:
# [1, 2, 3, 4]
